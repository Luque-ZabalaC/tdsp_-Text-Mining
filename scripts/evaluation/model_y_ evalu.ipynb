# %% [markdown]
# # Modelamiento y evaluación
# ---

# %%
# !apt-get install libgeos-dev
#!pip install https://github.com/matplotlib/basemap/archive/master.zip
# !pip install pyproj==1.9.6
# !pip install fasttext
# !python -m spacy download pt
# !pip install tensorflow_addons
# !pip install basemap

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import spacy
import regex as re
from datetime import datetime
from tqdm import tqdm
import pickle
import scipy
from mpl_toolkits.basemap import Basemap
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, OrdinalEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, log_loss
import fasttext.util
import warnings
from tensorflow_addons.metrics import F1Score
from sklearn.utils.extmath import randomized_svd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Embedding, LSTM, Flatten, Concatenate, Reshape, Conv1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from xgboost import XGBClassifier
from prettytable import PrettyTable
from keras.models import load_model
from sklearn.metrics import plot_confusion_matrix


warnings.filterwarnings("ignore")
sns.set_theme(style="darkgrid")
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
#Access drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Reading all the files
raw_path = '/content/drive/MyDrive/ColabNotebooks/06_MetodologiasAgiles/Project/'
#raw_path ='/content/drive/MyDrive/Colab Notebooks/06_MetodologiasAgiles/Project/output_folder/'
X_train = np.loadtxt(raw_path + 'X_train.txt')
X_test = np.loadtxt(raw_path + 'X_test.txt')
y_train = np.loadtxt(raw_path + 'y_train.txt')
y_test = np.loadtxt(raw_path + 'y_test.txt')

# %%
# Modeling
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import lightgbm as lgb

# %%
# Logistic Regression hyperparameters
logreg_param_grid = {
    'C': np.linspace(0.1, 10, 20),
    'penalty': ['l1', 'l2'],
    'class_weight': ['balanced', None],
    'random_state': [42],
    'solver': ['liblinear']
}

# Setting up the classifiers
set_classifiers = {
    'LogisticRegression': {
        'model': LogisticRegression(),
        'params': logreg_param_grid
    },
    'Naive Bayes': {
        'model': GaussianNB(),
        'params': {}
    }
}

# %%
# !pip install shap

# %%
from ml_utils import *
from viz_utils import *

# %%
# Creating an object and training the classifiers
clf_tool = BinaryClassifiersAnalysis()
clf_tool.fit(set_classifiers, X_train, y_train, random_search=True, scoring='accuracy')
# Out:
# Training model LogisticRegression
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training model Naive Bayes
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
# Evaluating metrics
df_performances = clf_tool.evaluate_performance(X_train, y_train, X_test, y_test, cv=5)
df_performances.reset_index(drop=True).style.background_gradient(cmap='Blues')
# Out:
# Evaluating model LogisticRegression
#
# Evaluating model Naive Bayes
# <style type="text/css">
# #T_36785_row0_col2, #T_36785_row0_col4, #T_36785_row0_col7, #T_36785_row1_col2, #T_36785_row1_col5, #T_36785_row1_col6, #T_36785_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_36785_row0_col3, #T_36785_row1_col7, #T_36785_row2_col2, #T_36785_row2_col4, #T_36785_row2_col5, #T_36785_row2_col6, #T_36785_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_36785_row0_col5 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_36785_row0_col6 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_36785_row1_col3 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_36785_row1_col4 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_36785_row2_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_36785_row2_col7 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_36785_row3_col2, #T_36785_row3_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_36785_row3_col6 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_36785_row3_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_36785_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >model</th>
#       <th class="col_heading level0 col1" >approach</th>
#       <th class="col_heading level0 col2" >acc</th>
#       <th class="col_heading level0 col3" >precision</th>
#       <th class="col_heading level0 col4" >recall</th>
#       <th class="col_heading level0 col5" >f1</th>
#       <th class="col_heading level0 col6" >auc</th>
#       <th class="col_heading level0 col7" >total_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36785_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36785_row0_col0" class="data row0 col0" >LogisticRegression</td>
#       <td id="T_36785_row0_col1" class="data row0 col1" >Treino 5 K-folds</td>
#       <td id="T_36785_row0_col2" class="data row0 col2" >0.885900</td>
#       <td id="T_36785_row0_col3" class="data row0 col3" >0.921600</td>
#       <td id="T_36785_row0_col4" class="data row0 col4" >0.923000</td>
#       <td id="T_36785_row0_col5" class="data row0 col5" >0.922300</td>
#       <td id="T_36785_row0_col6" class="data row0 col6" >0.943000</td>
#       <td id="T_36785_row0_col7" class="data row0 col7" >3.384000</td>
#     </tr>
#     <tr>
#       <th id="T_36785_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36785_row1_col0" class="data row1 col0" >LogisticRegression</td>
#       <td id="T_36785_row1_col1" class="data row1 col1" >Teste</td>
#       <td id="T_36785_row1_col2" class="data row1 col2" >0.886100</td>
#       <td id="T_36785_row1_col3" class="data row1 col3" >0.924200</td>
#       <td id="T_36785_row1_col4" class="data row1 col4" >0.920700</td>
#       <td id="T_36785_row1_col5" class="data row1 col5" >0.922500</td>
#       <td id="T_36785_row1_col6" class="data row1 col6" >0.945200</td>
#       <td id="T_36785_row1_col7" class="data row1 col7" >0.047000</td>
#     </tr>
#     <tr>
#       <th id="T_36785_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36785_row2_col0" class="data row2 col0" >Naive Bayes</td>
#       <td id="T_36785_row2_col1" class="data row2 col1" >Treino 5 K-folds</td>
#       <td id="T_36785_row2_col2" class="data row2 col2" >0.834100</td>
#       <td id="T_36785_row2_col3" class="data row2 col3" >0.944500</td>
#       <td id="T_36785_row2_col4" class="data row2 col4" >0.822200</td>
#       <td id="T_36785_row2_col5" class="data row2 col5" >0.879100</td>
#       <td id="T_36785_row2_col6" class="data row2 col6" >0.884500</td>
#       <td id="T_36785_row2_col7" class="data row2 col7" >1.973000</td>
#     </tr>
#     <tr>
#       <th id="T_36785_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36785_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_36785_row3_col1" class="data row3 col1" >Teste</td>
#       <td id="T_36785_row3_col2" class="data row3 col2" >0.835900</td>
#       <td id="T_36785_row3_col3" class="data row3 col3" >0.948100</td>
#       <td id="T_36785_row3_col4" class="data row3 col4" >0.821900</td>
#       <td id="T_36785_row3_col5" class="data row3 col5" >0.880500</td>
#       <td id="T_36785_row3_col6" class="data row3 col6" >0.887700</td>
#       <td id="T_36785_row3_col7" class="data row3 col7" >0.067000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_tool.plot_confusion_matrix(classes=['Negative', 'Positive'])
